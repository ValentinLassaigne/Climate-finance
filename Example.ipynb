# %%
import pandas as pd
import numpy as np

# %%
stocks = pd.read_excel('Individual_stock_data.xlsx',sheet_name='stock prices', index_col = 0)
stocks
# Out:
#                 AAPL       MSFT      AMZN      FB       JPM    GOOGL  \
# 1989-12-05    320.44     619.64       NaN     NaN    477.00      NaN
# 1989-12-12    256.35     589.29       NaN     NaN    488.96      NaN
# 1989-12-19    249.23     574.11       NaN     NaN    439.49      NaN
# 1989-12-26    252.79     610.71       NaN     NaN    450.91      NaN
# 1990-01-02    265.25     633.93       NaN     NaN    456.61      NaN
# ...              ...        ...       ...     ...       ...      ...
# 2019-11-12  64259.93  233797.60  90791.38  508.66  14527.80  2583.25
# 2019-11-19  65322.11  239075.40  89504.06  521.35  14687.52  2613.88
# 2019-11-26  64831.50  242506.30  91758.56  520.43  14810.12  2614.70
# 2019-12-03  63644.21  238167.60  90380.81  520.04  14597.53  2578.33
# 2019-12-10  65859.31  241070.70  88810.63  525.40  15128.43  2674.22
#
#                  JNJ        WMT        V      BAC  ...     PWR    TRIP  \
# 1989-12-05    382.85    9096.68      NaN   512.75  ...     NaN     NaN
# 1989-12-12    386.18    9096.68      NaN   502.75  ...     NaN     NaN
# 1989-12-19    373.70    8839.71      NaN   475.61  ...     NaN     NaN
# 1989-12-26    379.52    8916.80      NaN   519.89  ...     NaN     NaN
# 1990-01-02    398.67    9687.71      NaN   532.74  ...     NaN     NaN
# ...              ...        ...      ...      ...  ...     ...     ...
# 2019-11-12  13782.20  297373.40  1379.37  3493.60  ...  571.17  115.48
# 2019-11-19  14146.30  299295.70  1404.96  3477.76  ...  562.46  116.26
# 2019-11-26  14492.55  297548.30  1403.27  3521.05  ...  558.04  119.25
# 2019-12-03  14491.49  296250.10  1398.27  3467.20  ...  544.25  114.34
# 2019-12-10  14790.49  298751.90  1401.04  3559.31  ...  534.47  118.68
#
#                UNM   BRK/B    GOOG   DISCK    FOX    NWS     UA    VIAB
# 1989-12-05  180.07     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 1989-12-12  180.07     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 1989-12-19  172.06     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 1989-12-26  176.30     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 1990-01-02  180.07     NaN     NaN     NaN    NaN    NaN    NaN     NaN
# ...            ...     ...     ...     ...    ...    ...    ...     ...
# 2019-11-12  803.75  952.11  233.21  356.00  87.40  91.57  37.81  209.88
# 2019-11-19  780.03  944.09  236.20  365.31  91.59  91.30  37.88  219.14
# 2019-11-26  803.22  943.53  235.85  387.25  90.97  91.64  39.97  225.00
# 2019-12-03  771.24  940.00  232.57  374.69  88.80  88.82  40.36  218.39
# 2019-12-10  798.15  953.71  241.44  374.87  90.27  92.54  42.93  225.37
#
# [1567 rows x 505 columns]

# %%
newdf = stocks.select_dtypes(include='object')
for column in newdf.columns:
    stocks = stocks.drop(column, axis = 1)

# %%
stocks = stocks.pct_change()

# %%
stocks
# Out:
#                 AAPL      MSFT      AMZN        FB       JPM     GOOGL  \
# 1989-12-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1989-12-12 -0.200006 -0.048980       NaN       NaN  0.025073       NaN
# 1989-12-19 -0.027775 -0.025760       NaN       NaN -0.101174       NaN
# 1989-12-26  0.014284  0.063751       NaN       NaN  0.025985       NaN
# 1990-01-02  0.049290  0.038021       NaN       NaN  0.012641       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-11-12  0.021808  0.018068 -0.013160  0.000767  0.000465  0.004468
# 2019-11-19  0.016529  0.022574 -0.014179  0.024948  0.010994  0.011857
# 2019-11-26 -0.007511  0.014351  0.025189 -0.001765  0.008347  0.000314
# 2019-12-03 -0.018313 -0.017891 -0.015015 -0.000749 -0.014354 -0.013910
# 2019-12-10  0.034804  0.012189 -0.017373  0.010307  0.036369  0.037191
#
#                  JNJ       WMT         V       BAC  ...       PWR      TRIP  \
# 1989-12-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1989-12-12  0.008698  0.000000       NaN -0.019503  ...       NaN       NaN
# 1989-12-19 -0.032317 -0.028249       NaN -0.053983  ...       NaN       NaN
# 1989-12-26  0.015574  0.008721       NaN  0.093101  ...       NaN       NaN
# 1990-01-02  0.050458  0.086456       NaN  0.024717  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-11-12  0.007131  0.002187  0.019113  0.008228  ... -0.025141 -0.226472
# 2019-11-19  0.026418  0.006464  0.018552 -0.004534  ... -0.015249  0.006754
# 2019-11-26  0.024476 -0.005838 -0.001203  0.012448  ... -0.007858  0.025718
# 2019-12-03 -0.000073 -0.004363 -0.003563 -0.015294  ... -0.024711 -0.041174
# 2019-12-10  0.020633  0.008445  0.001981  0.026566  ... -0.017970  0.037957
#
#                  UNM     BRK/B      GOOG     DISCK       FOX       NWS  \
# 1989-12-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1989-12-12  0.000000       NaN       NaN       NaN       NaN       NaN
# 1989-12-19 -0.044483       NaN       NaN       NaN       NaN       NaN
# 1989-12-26  0.024643       NaN       NaN       NaN       NaN       NaN
# 1990-01-02  0.021384       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-11-12  0.007685  0.000042  0.005259  0.089952  0.051618 -0.062071
# 2019-11-19 -0.029512 -0.008423  0.012821  0.026152  0.047941 -0.002949
# 2019-11-26  0.029730 -0.000593 -0.001482  0.060059 -0.006769  0.003724
# 2019-12-03 -0.039815 -0.003741 -0.013907 -0.032434 -0.023854 -0.030773
# 2019-12-10  0.034892  0.014585  0.038139  0.000480  0.016554  0.041882
#
#                   UA      VIAB
# 1989-12-05       NaN       NaN
# 1989-12-12       NaN       NaN
# 1989-12-19       NaN       NaN
# 1989-12-26       NaN       NaN
# 1990-01-02       NaN       NaN
# ...              ...       ...
# 2019-11-12 -0.044720  0.007392
# 2019-11-19  0.001851  0.044120
# 2019-11-26  0.055174  0.026741
# 2019-12-03  0.009757 -0.029378
# 2019-12-10  0.063677  0.031961
#
# [1567 rows x 503 columns]

# %%
stocks = stocks.iloc[1:]

# %%
index = pd.read_excel('Individual_stock_data.xlsx',sheet_name='SP500',index_col = 0)
index
# Out:
#             S&P 500 COMPOSITE - TOT RETURN IND
# Name
# 1989-12-05                              374.62
# 1989-12-12                              377.14
# 1989-12-19                              367.27
# 1989-12-26                              372.23
# 1990-01-02                              386.16
# ...                                        ...
# 2019-11-12                             6253.91
# 2019-11-19                             6314.66
# 2019-11-26                             6358.46
# 2019-12-03                             6265.22
# 2019-12-10                             6348.31
#
# [1567 rows x 1 columns]

# %%
index = index.pct_change()
index = index.iloc[1:]
index
# Out:
#             S&P 500 COMPOSITE - TOT RETURN IND
# Name
# 1989-12-12                            0.006727
# 1989-12-19                           -0.026171
# 1989-12-26                            0.013505
# 1990-01-02                            0.037423
# 1990-01-09                           -0.027450
# ...                                        ...
# 2019-11-12                            0.006377
# 2019-11-19                            0.009714
# 2019-11-26                            0.006936
# 2019-12-03                           -0.014664
# 2019-12-10                            0.013262
#
# [1566 rows x 1 columns]

# %%
static_data = pd.read_excel('Individual_stock_data.xlsx',sheet_name='carbon footprint data')
static_data
# Out:
#     Unnamed: 0                               NAME  SECTOR  \
# 0         AAPL                              APPLE      45
# 1         MSFT                          MICROSOFT      45
# 2         AMZN                         AMAZON.COM      25
# 3           FB                   FACEBOOK CLASS A      50
# 4          JPM              JP MORGAN CHASE & CO.      40
# ..         ...                                ...     ...
# 500      DISCK                 DISCOVERY SERIES C      50
# 501        FOX                              FOX B      50
# 502        NWS                           NEWS 'B'      50
# 503         UA                   UNDER ARMOUR 'C'      25
# 504       VIAB  VIACOM 'B' DEAD - DELIST.05/12/19      50
#
#                 SECTOR_NAME       SCOPE1       SCOPE2    EMISSIONS  \
# 0                        IT    45.397000   776.500000   821.897000
# 1                        IT    97.639000  2692.709000  2790.348000
# 2    Consumer Discretionary  4980.000000  4710.000000  9690.000000
# 3    Communication Services    18.900000  1137.000000  1155.900000
# 4                 Financial    78.229000   770.704000   848.933000
# ..                      ...          ...          ...          ...
# 500  Communication Services          NaN          NaN          NaN
# 501  Communication Services    60.395000   120.093000   180.488000
# 502  Communication Services    28.356311   173.658313   202.014624
# 503  Consumer Discretionary          NaN          NaN          NaN
# 504  Communication Services          NaN          NaN          NaN
#
#      MARKET_VALUE    REVENUES  CARBON_FOOTPRINT  INTENSITY
# 0      1206167.00  260174.000          0.681412   3.159028
# 1      1169037.00  125843.000          2.386877  22.173248
# 2       872766.50  232887.000         11.102626  41.608162
# 3       473472.70   55838.000          2.441323  20.700956
# 4       432897.40  131412.000          1.961049   6.460087
# ..            ...         ...               ...        ...
# 500      10855.98   10553.000               NaN        NaN
# 501       9571.59   11389.000         18.856637  15.847572
# 502       2800.81   10074.000         72.127215  20.053070
# 503       4008.28    5193.185               NaN        NaN
# 504       8573.32         NaN               NaN        NaN
#
# [505 rows x 11 columns]

# %%
static_data = static_data.rename(columns={'Unnamed: 0': 'StockNames'})
static_data.set_index(['StockNames'], inplace=True)
static_data = static_data[['SECTOR','SECTOR_NAME','INTENSITY']]
for ind in newdf.columns:
    static_data = static_data.drop(ind, axis = 0)

# %%
static_data
# Out:
#             SECTOR             SECTOR_NAME  INTENSITY
# StockNames
# AAPL            45                      IT   3.159028
# MSFT            45                      IT  22.173248
# AMZN            25  Consumer Discretionary  41.608162
# FB              50  Communication Services  20.700956
# JPM             40               Financial   6.460087
# ...            ...                     ...        ...
# DISCK           50  Communication Services        NaN
# FOX             50  Communication Services  15.847572
# NWS             50  Communication Services  20.053070
# UA              25  Consumer Discretionary        NaN
# VIAB            50  Communication Services        NaN
#
# [503 rows x 3 columns]

# %%
stocks
# Out:
#                 AAPL      MSFT      AMZN        FB       JPM     GOOGL  \
# 1989-12-12 -0.200006 -0.048980       NaN       NaN  0.025073       NaN
# 1989-12-19 -0.027775 -0.025760       NaN       NaN -0.101174       NaN
# 1989-12-26  0.014284  0.063751       NaN       NaN  0.025985       NaN
# 1990-01-02  0.049290  0.038021       NaN       NaN  0.012641       NaN
# 1990-01-09  0.010066  0.022526       NaN       NaN  0.008344       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-11-12  0.021808  0.018068 -0.013160  0.000767  0.000465  0.004468
# 2019-11-19  0.016529  0.022574 -0.014179  0.024948  0.010994  0.011857
# 2019-11-26 -0.007511  0.014351  0.025189 -0.001765  0.008347  0.000314
# 2019-12-03 -0.018313 -0.017891 -0.015015 -0.000749 -0.014354 -0.013910
# 2019-12-10  0.034804  0.012189 -0.017373  0.010307  0.036369  0.037191
#
#                  JNJ       WMT         V       BAC  ...       PWR      TRIP  \
# 1989-12-12  0.008698  0.000000       NaN -0.019503  ...       NaN       NaN
# 1989-12-19 -0.032317 -0.028249       NaN -0.053983  ...       NaN       NaN
# 1989-12-26  0.015574  0.008721       NaN  0.093101  ...       NaN       NaN
# 1990-01-02  0.050458  0.086456       NaN  0.024717  ...       NaN       NaN
# 1990-01-09 -0.018787 -0.029178       NaN -0.029489  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-11-12  0.007131  0.002187  0.019113  0.008228  ... -0.025141 -0.226472
# 2019-11-19  0.026418  0.006464  0.018552 -0.004534  ... -0.015249  0.006754
# 2019-11-26  0.024476 -0.005838 -0.001203  0.012448  ... -0.007858  0.025718
# 2019-12-03 -0.000073 -0.004363 -0.003563 -0.015294  ... -0.024711 -0.041174
# 2019-12-10  0.020633  0.008445  0.001981  0.026566  ... -0.017970  0.037957
#
#                  UNM     BRK/B      GOOG     DISCK       FOX       NWS  \
# 1989-12-12  0.000000       NaN       NaN       NaN       NaN       NaN
# 1989-12-19 -0.044483       NaN       NaN       NaN       NaN       NaN
# 1989-12-26  0.024643       NaN       NaN       NaN       NaN       NaN
# 1990-01-02  0.021384       NaN       NaN       NaN       NaN       NaN
# 1990-01-09  0.020936       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-11-12  0.007685  0.000042  0.005259  0.089952  0.051618 -0.062071
# 2019-11-19 -0.029512 -0.008423  0.012821  0.026152  0.047941 -0.002949
# 2019-11-26  0.029730 -0.000593 -0.001482  0.060059 -0.006769  0.003724
# 2019-12-03 -0.039815 -0.003741 -0.013907 -0.032434 -0.023854 -0.030773
# 2019-12-10  0.034892  0.014585  0.038139  0.000480  0.016554  0.041882
#
#                   UA      VIAB
# 1989-12-12       NaN       NaN
# 1989-12-19       NaN       NaN
# 1989-12-26       NaN       NaN
# 1990-01-02       NaN       NaN
# 1990-01-09       NaN       NaN
# ...              ...       ...
# 2019-11-12 -0.044720  0.007392
# 2019-11-19  0.001851  0.044120
# 2019-11-26  0.055174  0.026741
# 2019-12-03  0.009757 -0.029378
# 2019-12-10  0.063677  0.031961
#
# [1566 rows x 503 columns]

# %%
index
# Out:
#             S&P 500 COMPOSITE - TOT RETURN IND
# Name
# 1989-12-12                            0.006727
# 1989-12-19                           -0.026171
# 1989-12-26                            0.013505
# 1990-01-02                            0.037423
# 1990-01-09                           -0.027450
# ...                                        ...
# 2019-11-12                            0.006377
# 2019-11-19                            0.009714
# 2019-11-26                            0.006936
# 2019-12-03                           -0.014664
# 2019-12-10                            0.013262
#
# [1566 rows x 1 columns]

# %%
def portfolio_return(weights,stocks):
    return(pd.DataFrame(((weights*stocks).transpose()).sum(),index = index.index))

# %%
from scipy.optimize import minimize
    
def mTE(stocks,indx):
    """
    Returns the weights of the portfolio that gives you the maximum sharpe ratio
    given the riskfree rate and expected returns and a covariance matrix
    """
    n = stocks.shape[1]
    T = stocks.shape[0]
    init_guess = np.repeat(1/n, n)
    bounds = ((0.0, 1.0),) * n # an N-tuple of 2-tuples!
    # construct the constraints
    weights_sum_to_1 = {'type': 'eq',
                        'fun': lambda weights: np.sum(weights) - 1
    }
    def TE(weights, stocks, indx):
        """
        Returns the tracking error
        """
        r = portfolio_return(weights, stocks)
        diff = r.values - indx.values
        return ((diff)**2/T).sum()
    
    weights = minimize(TE, init_guess,
                       args=(stocks, indx), method='SLSQP',
                       options={'disp': False},
                       constraints=(weights_sum_to_1,),
                       bounds=bounds)
    return weights.x

# %%
stocks['AAPL']['1989-12-12']
# Out:
# -0.20000624141805012

# %%
w = mTE(stocks,index)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(w)

# %%
w.shape[0]
# Out:
# 503

# %%
index_CI = (w*static_data['INTENSITY']).sum()    # Intensité carbone de l'index (à utiliser dans les contraines)
# Out:
# 503

# %%
SECTORS=static_data['SECTOR'].unique()
ratio=np.zeros(len(SECTORS))
selected=[]
for k,i in enumerate(SECTORS) :
    ratio[k]=(static_data.loc[static_data['SECTOR']==i].SECTOR.count())/len(static_data)
    selected.append(static_data.loc[static_data['SECTOR']==i].sort_values(by=['INTENSITY'])[:int(ratio[k]*50)+1])

# %%
#static_data.loc[static_data['SECTOR']==i].INTENSITY.count()
m=0
list=[]
for i in range(11):
    list.append(selected[i])

list

pos_scr=pd.concat(list).sort_values(by=['INTENSITY'])

# %%
stocks2=stocks[pos_scr.index]

# %%
def portfolio_return(weights,stocks):
    return(pd.DataFrame(((weights*stocks).transpose()).sum(),index = index.index))

# %%
from scipy.optimize import minimize
    
def mTE(stocks,indx):
    """
    Returns the weights of the portfolio that gives you the maximum sharpe ratio
    given the riskfree rate and expected returns and a covariance matrix
    """
    n = stocks2.shape[1]
    T = stocks2.shape[0]
    init_guess = np.repeat(1/n, n)
    bounds = ((0.0, 1.0),) * n # an N-tuple of 2-tuples!
    # construct the constraints
    weights_sum_to_1 = {'type': 'eq',
                        'fun': lambda weights: np.sum(weights) - 1
    }
    def TE(weights, stocks, indx):
        """
        Returns ENC
        """
        #return (1/(weights[i]**2).sum())
        return -1/sum(weights[i]**2 for i in range(len(weights)))
    weights = minimize(TE, init_guess,
                       args=(stocks, indx), method='SLSQP',
                       options={'disp': False},
                       constraints=(weights_sum_to_1,),
                       bounds=bounds)
    return weights.x

w = mTE(stocks,index)
w
# Out:
# array([0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852, 0.01851852,
#        0.01851852, 0.01851852, 0.01851852, 0.01851852])
